# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages.human import HumanMessage
import os

api_key = os.environ.get("GOOGLE_API_KEY")
print(f"api google: {api_key}")
if api_key is None:
    raise ValueError("No se encontró la variable de entorno GOOGLE_API_KEY")


llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.7)

pregunta = input("¿Pregunta?: ")
print(f"\033[92mmira negrin hice una ia:\033[0m {pregunta}\n\n")
mensaje = HumanMessage(content=pregunta)

respuesta = llm.invoke([mensaje])
print("Respuesta:", respuesta.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
import os

chat = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.7)
plantilla = PromptTemplate(
            input_variables=["nombre"],
            template="Saluda al usuario con su nombre.\nNombre del usuario: {nombre} \n  Asistente:"
            )

#Encadenamos operaciones con | (operador pipe o tubería)
chain = plantilla | chat
resultado = chain.invoke({"nombre": "Jorge"})
print(resultado.content)

# %% [markdown]
# -----------------
# OLLAMA
# -----------------

# %%
from langchain_ollama.llms import OllamaLLM

llm = OllamaLLM(model="llama3.2", base_url="http://localhost:11434")

pregunta = input("que quieres preguntar")

respuesta = llm.invoke(pregunta)

print("respuesta_ ", respuesta)

# %% [markdown]
# -------------------
# STREAMLIT-
# -------------------

# %%
import streamlit as st
from langchain_google_genai import ChatGoogleGenerativeAI
# Configuración inicial
st.set_page_config(page_title="Chatbot Básico", page_icon=" ")
st.title(" Chatbot Básico con LangChain")
st.markdown("Este es un *chatbot de ejemplo* construido con LangChain + 
Streamlit.")
chat_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
# Out:
#   Cell In[14], line 6
#     st.markdown("Este es un *chatbot de ejemplo* construido con LangChain +
#                 ^
# SyntaxError: unterminated string literal (detected at line 6)
