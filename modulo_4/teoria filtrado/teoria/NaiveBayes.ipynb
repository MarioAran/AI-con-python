# %% [markdown]
# # Naive Bayes

# %%
import os
import random
import shutil
import io
import numpy
import pandas as pd
from pandas import DataFrame
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

def copy(name):
    originalfolder = "data/emails/emails/"+name
    copy_ham = "data/emails/train/"+name
    copy_test = "data/emails/test/"+name  # Carpeta para el 20% restante

    for carpeta in [copy_ham, copy_test]:
        if not os.path.exists(carpeta):
            os.makedirs(carpeta)
    if not os.path.exists(originalfolder):
        raise FileNotFoundError(f"La carpeta de origen no existe: {originalfolder}")

    archivos = [f for f in os.listdir(originalfolder) if os.path.isfile(os.path.join(originalfolder, f))]

    if len(archivos) == 0:
        raise ValueError("No hay archivos en la carpeta de origen.")

    random.shuffle(archivos)
    cantidad_train = int(len(archivos) * 0.8)

    archivos_train = archivos[:cantidad_train]
    archivos_test = archivos[cantidad_train:]

    for archivo in archivos_train:
        shutil.copy2(os.path.join(originalfolder, archivo), os.path.join(copy_ham, archivo))

    for archivo in archivos_test:
        shutil.copy2(os.path.join(originalfolder, archivo), os.path.join(copy_test, archivo))
copy("ham")
copy("spam")

# %%
#Retorna la ruta completa del archivo y su contenido (sin la cabecera)
def readFiles(path):
    #os.walk itera sobre todos los archivos de una carpeta
    for root, dirnames, filenames in os.walk(path):
        for filename in filenames:
            path = os.path.join(root, filename)

            inBody = False
            lines = []
            f = io.open(path, 'r', encoding='latin1')
            for line in f:
                if inBody:
                    lines.append(line)
                #se salta todo el encabezado y empieza a leer en el 
                #primera linea vacía
                elif line == '\n':
                    inBody = True
            f.close()
            #Join all items in a list into a string, using a \n as separator
            message = '\n'.join(lines)
            yield path, message

def dataFrameFromDirectory_test(path):
    rows = []
    index = []
    for filename, message in readFiles(path):
        rows.append({'message': message})
        index.append(filename)

    return DataFrame(rows, index=index)

def dataFrameFromDirectory(path, classification):
    rows = []
    index = []
    for filename, message in readFiles(path):
        rows.append({'message': message, 'class': classification})
        index.append(filename)

    return DataFrame(rows, index=index)

#Un DataFrame con dos columnas, uno contiene el contenido del correo y el otro el tipo (spam o ham) 
data = DataFrame({'message': [], 'class': []})

#data = data.append(dataFrameFromDirectory('./datos/emails/spam', 'spam'))
#data = data.append(dataFrameFromDirectory('./datos/emails/ham', 'ham'))

# Un DataFrame con dos columnas, uno contiene el contenido del correo y el otro el tipo (spam o ham)
data_train_spam = dataFrameFromDirectory('data/emails/train/spam', 'spam')
data_train_ham = dataFrameFromDirectory('data/emails/train/ham', 'ham')
data_train = pd.concat([data_train_spam, data_train_ham], ignore_index=True)

# %%
data_train.head()
# Out:
#                                              message class
# 0  Dear Homeowner,\n\n \n\nInterest Rates are at ...  spam
# 1  ATTENTION: This is a MUST for ALL Computer Use...  spam
# 2  This is a multi-part message in MIME format.\n...  spam
# 3  IMPORTANT INFORMATION:\n\n\n\nThe new domain n...  spam
# 4  This is the bottom line.  If you can GIVE AWAY...  spam

# %%
vectorizer = CountVectorizer()
counts = vectorizer.fit_transform(data_train['message'].values)

print('\ncounts')
print(type(counts))
counts
# Out:
# counts
# <class 'scipy.sparse._csr.csr_matrix'>
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 431104 stored elements and shape (3000, 63860)>

# %%
targets = data_train['class'].values

print('\ntargets')
print(type(targets))
print("Shape:", targets.shape)  
print("Dimensions:", targets.ndim)
# Out:
# targets
# <class 'numpy.ndarray'>
# Shape: (3000,)
# Dimensions: 1

# %%
classifier = MultinomialNB()
classifier.fit(counts, targets)
# Out:
# MultinomialNB()

# %% [markdown]
# Probamos con algunos ejemplos:

# %%
data_test_spam = dataFrameFromDirectory_test('data/emails/test/spam')
data_test_ham = dataFrameFromDirectory_test('data/emails/test/ham')
data = pd.concat([data_test_spam, data_test_ham], ignore_index=True)

prediction = []  # asegúrate de que esté inicializada
for idx, row in data.iterrows():
    message = row['message']
    example_counts = vectorizer.transform([message])
    pred = classifier.predict(example_counts)[0]
    prediction.append((pred, message))  # guarda ambos valores

print("\nPredicciones realizadas:")
for pred, msg in prediction:
    print(f"{pred} -- msg: \"{msg[:50]}\"")
# Out:
# Predicciones realizadas:
# spam -- msg: "Dear Homeowner,
#
#
#
# Interest Rates are at their lo"
# spam -- msg: "; Thu, 19 Sep 2002 11:30:56 +0100
#
#     (may be for"
# spam -- msg: "=20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# Call today for "
# ham -- msg: "This is the bottom line.  If you can GIVE AWAY CD'"
# spam -- msg: "------=_NextPart_000_00B8_51E06B6A.C8586B31
#
# Conte"
# spam -- msg: "<HR>
#
# <html>
#
# <head>
#
#   <title>Secured Investement"
# spam -- msg: "<table width="600" border="20" align="center" bord"
# spam -- msg: "Unlist Information
#
#
#
# 		This message is brought to"
# spam -- msg: "Dear Consumers, Increase your Business Sales!
#
#
#
# "
# ham -- msg: "; Tue, 24 Sep 2002 15:15:57 +0100
#
#     webnote.net"
# ham -- msg: "UNLIMITED WEB CON=
#
# FERENCING
#
#
#
# Subscribe to the "
# spam -- msg: "------=_NextPart_000_00A3_65E24E1C.A3468E63
#
#
#
# Q09"
# spam -- msg: "=20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
#         "
# ham -- msg: "; Thu, 22 Aug 2002 16:34:25 +0100
#
#     (8.9.3/8.9."
# spam -- msg: "ABIDJAN, IVORY COAST
#
# WEST-AFRICA.
#
#
#
# DEAR,
# "
# spam -- msg: "Check the Available REPORTS you would like to rece"
# ham -- msg: "
#
# WET, HORNY AND DIRTY GRANDMAS!
#
#
#
# Remember how y"
# spam -- msg: "Beautiful, 100% Custom
#
#       Websites, $349 Comp"
# spam -- msg: "------=_NextPart_000_00C2_37C70C2D.A8844B81
#
# Conte"
# spam -- msg: "Itâs FAST!
#
#  Youâll be up and running in an ho"
# ham -- msg: "; Mon, 9 Sep 2002 10:18:17 +0100
#
#
#
# It was the Spr"
# ham -- msg: "Dear User,
#
#
#
# Do you ever wish you could easily ca"
# spam -- msg: "This e-mail is intended to be a benefit to the rec"
# ham -- msg: "BOOST
#
#         Your Reception
#
#
#
# on
#
#         any"
# spam -- msg: "; Sun, 22 Sep 2002 15:01:41 +0100
#
#     with SMTP i"
# spam -- msg: "; Sun, 22 Sep 2002 05:37:15 +0100
#
#     [200.170.14"
# spam -- msg: "Dear Sir or Madam:
#
#
#
# Please reply to
#
#
#
# As one t"
# spam -- msg: "Lowest rates available for term life insurance! Ta"
# spam -- msg: "<HTML>
#
# <PRE>
#
# Dear Valued Member,
#
#
#
# OfferClub wo"
# spam -- msg: "Dear Sir / Madam
#
#
#
# If you are fed up of being 'ri"
# ham -- msg: ""
# ham -- msg: "TIRED OF THE BULL OUT THERE?
#
# Want To Stop Losing "
# spam -- msg: "Cellular Phone Accessories All At Below Wholesale "
# ham -- msg: "Dear Sir or Madam:
#
#
#
# Please reply to
#
# Receiver: "
# ham -- msg: "; Wed, 28 Aug 2002 18:04:09 +0100
#
#     Aug, 28 200"
# spam -- msg: "Get your favorite Poker action at http://www.multi"
# ham -- msg: ""
# spam -- msg: "<html>
#
# <head>
#
# </head>
#
# <body>
#
# <p align="center""
# spam -- msg: "<html>
#
# <head>
#
# <title>Digital Publishing Tools - "
# spam -- msg: "Lowest rates available for term life insurance!
#
# "
# ham -- msg: "; Thu, 26 Sep 2002 10:52:46 +0100
#
#     (Postfix) w"
# spam -- msg: "=
#
#
#
# Take
#
#       Control of Your Computer With Thi"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# spam -- msg: "##################################################"
# spam -- msg: "OFFICE OF:EGNR. FEMI DANIEL
#
# FEDERAL MINISTRY OF W"
# spam -- msg: "NEWSLETTER COACHINVEST  SEPTEMBRE 2002
#
#
#
# Coach"
# spam -- msg: "HELLO...By reading the short Summary just below, y"
# ham -- msg: "Hi -
#
#
#
# ( http://club.4tfox.com )
#
#
#
# You get email"
# spam -- msg: "click this link
#
# .
#
# Please accept our apologies i"
# spam -- msg: "Does Your Comp=
#
# uter Need an Oil
#
#       Change?
#
# "
# ham -- msg: "Hi,
#
#
#
# I'm a college dropout.  I work about two ho"
# ham -- msg: "; Wed, 25 Sep 2002 16:22:26 +0100
#
#     (8.9.3/8.9."
# spam -- msg: "
#
# PUBLIC ANNOUNCEMENT:
#
#
#
# The new domain names are"
# spam -- msg: "IS YOUR BUSINESS MAKING MONEY!
#
# Set Up To Accept C"
# spam -- msg: "HOSTING from an =
#
# Irish company=20
#
# from as littl"
# spam -- msg: " Would You Like to
#
#
#
#  Save
#
# up to
#
#
#
# 80%
#
#
#
#     "
# spam -- msg: "This is a multi-part message in MIME format.
#
# --NS"
# spam -- msg: "; Mon, 23 Sep 2002 17:51:37 +0100
#
#     [64.25.33.4"
# spam -- msg: "; Tue, 27 Aug 2002 20:21:30 +0100
#
#     with SMTP; "
# ham -- msg: "; Tue, 3 Dec 2002 12:37:37 GMT
#
#     (Postfix) with"
# spam -- msg: "<html>
#
# <body>
#
# <p>Do you like Sexy Animals doing "
# spam -- msg: "
#
# <html>
#
# <head>
#
#
#
# </head>
#
# <body bgcolor=#FFFFFF"
# ham -- msg: "
#
#
#
# social
#
#
#
#
#
#
#
# On January 1st 2002, the Europea"
# spam -- msg: "LOWEST RATES IN 45 YEARS -
#
# FILL OUT OUR SHORT APP"
# ham -- msg: "; Tue, 24 Sep 2002 14:40:49 +0100
#
#     (Postfix) w"
# spam -- msg: "Protect your financial well-being.
#
# Purchase an Ex"
# spam -- msg: "=================================================="
# spam -- msg: "<!-- saved from url=(0022)http://internet.e-mail -"
# spam -- msg: "Click
#
#  HERE For Details!
#
#
#
# We Only Have HIGH QU"
# spam -- msg: "<html>
#
# <head>
#
# <title>Untitled Document</title>
#
# "
# spam -- msg: "We guarantee you signups before you ever pay
#
# a pe"
# spam -- msg: "Wind up your mates today! Please visit http://ukpr"
# ham -- msg: "Greetings!
#
#
#
# You are receiving this letter becau"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# spam -- msg: "<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transi"
# spam -- msg: "WERKEN BIJ DE LOTTO,
#
# 41132, NL-1007 DB AMSTERDAM,"
# spam -- msg: "------=_NextPart_000_00D7_08E60D5B.E5437E70
#
#
#
# PGh"
# spam -- msg: "
#
# <html><body><center>
#
#
#
# <table bgcolor=3D"0080C0"
# spam -- msg: "Â Â =
#
#
#
# quotepool
#
# mortgageâ¢
#
#
#
# We're different"
# spam -- msg: "<html>
#
# <body>
#
# <p>Do you like Sexy Animals doing "
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# spam -- msg: "<html>
#
#
#
# <head>
#
# <meta http-equiv=3D"Content-Lang"
# ham -- msg: ""
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# ham -- msg: "ààªÍ¶¯ÄÔÇ¤ªäêé
#
# µ¶ÝÆààÌR{"
# spam -- msg: "<html>
#
# <head>
#
# <meta http-equiv="content-type" co"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# spam -- msg: "
#
# Question?
#
#
#
# Do you want a different job?
#
# Do yo"
# spam -- msg: "
#
#                  Do You Want To Teach and Grow "
# spam -- msg: "Opportunity is knocking. Why?
#
#
#
# Because mortgage "
# spam -- msg: "<html>
#
#
#
# <head>
#
# <meta http-equiv=3D"Content-Lang"
# spam -- msg: "<html>
#
# <head>
#
# <title>mailv07a.gif</title>
#
# <meta"
# spam -- msg: "=============================================
#
# Bra"
# ham -- msg: "It was the Spring of 1979.
#
#
#
# I was just a tall,"
# spam -- msg: "Get your favorite Poker action at http://www.multi"
# spam -- msg: "Get your favorite Poker action at http://www.multi"
# spam -- msg: "=
#
#
#
# Take
#
#       Control of Your Computer With Thi"
# spam -- msg: "      relevant Sales, Marketing & Advertising Arti"
# spam -- msg: "Join her in our Live Teen Chat!
#
#
#
# Watch as Sandy "
# ham -- msg: " ilug ,
#
#
#
#  From;Mr.Michael Kamah and Family,
#
#    "
# ham -- msg: "; Sat, 24 Aug 2002 13:49:40 +0100
#
#     (8.9.3/8.9."
# ham -- msg: "$ 39+KDV
#
#
#
#  NGLZCE'DEN TRKE'YE BLGSAYAR DESTEKL
#
# "
# spam -- msg: "Conferencing Made=
#
#  Easy
#
#
#
# Only
#
# 18 Cents
#
#  Per"
# spam -- msg: "Ã£
#
#     Å´ÅµÐ±Ç¸ë½«É¾
#
#     ÒªÒµÕ¾Æ¹ß²Æ·Ï¢EMAILÓªÏµ"
# spam -- msg: "<html>
#
# <head>
#
# <title></title>
#
# </head>
#
# <body bg"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# ham -- msg: "; Thu, 26 Sep 2002 07:22:14 +0100
#
#     (8.9.3/8.9."
# spam -- msg: "<html>
#
# <head>
#
# </head>
#
# <body>
#
# <p align="center""
# spam -- msg: "YOUR SEX DRIVE SHOULD NEVER BE SECOND ON THE LIST!"
# ham -- msg: "R
#
# E
#
# A
#
# D
#
#
#
# M
#
# Y
#
#
#
# L
#
# I
#
# P
#
# S
#
# tick
#
#
#
# !
#
#
#
# L
#
# "
# spam -- msg: "=20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# Full-Time Agent"
# ham -- msg: "Hello
#
#
#
# You may have seen this business before an"
# spam -- msg: "on Toners,Â
#
#
#
# Inkjets, FAX, and Thermal Replenis"
# spam -- msg: "<HTML><HEAD><TITLE>Big and big</TITLE>
#
# <META http"
# spam -- msg: "Note:
#
# This is NOT SPAM!! This is NOT Unsolicited"
# ham -- msg: "INVESTMENT SCHOLARS CLUB- bringing you the latest "
# spam -- msg: "Dear Homeowner,
#
#
#
# Interest Rates are at their lo"
# spam -- msg: "<html>
#
#
#
# <head>
#
# <title>Home Page</title>
#
# </head"
# spam -- msg: "Congratulations JM@NETNOTEINC.COM!
#
#
#
# Dear JM@NETN"
# spam -- msg: "; Thu, 26 Sep 2002 13:23:45 +0100
#
#     [200.204.18"
# spam -- msg: "<html>
#
# <head>
#
# </head>
#
# <body>
#
#
#
# <center>
#
# <font"
# spam -- msg: "=20
#
#
#
# http://www.efi.ie/index-1998-07-16.html"
# spam -- msg: "Dear ricardo1 ,
#
#
#
# <html>
#
# <body>
#
# <center>
#
# <b><f"
# ham -- msg: "Hello
#
#
#
# You may have seen this business before an"
# spam -- msg: "Help wanted.  We are a 14 year old fortune 500 com"
# spam -- msg: "=20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# Case =
#
# Closed!"
# spam -- msg: "<html>
#
# <head>
#
# <title>FREE* Liz Claiborne&reg; Fr"
# spam -- msg: "
#
#
#
#                           ********************"
# ham -- msg: "Hello, my name is Kelly, I am an 18 year old swimm"
# spam -- msg: " <p>We thank you for just a moment of your time.  "
# spam -- msg: "SUBSTANTIAL MONTHLY INCOME MAKERS VOUCHER
#
# Income "
# spam -- msg: "
#
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0//EN""
# ham -- msg: "; Fri, 13 Sep 2002 07:20:06 +0100
#
#     (8.9.3/8.9."
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# spam -- msg: "Dear Sir/Madam,
#
#
#
# My name is Petr Stanek and I am"
# spam -- msg: "Market Internet Access
#
#
#
# No Investment Needed
#
# "
# spam -- msg: "=================================
#
#
#
# Guaranteed to"
# ham -- msg: "; Sat, 7 Sep 2002 06:47:31 +0100
#
#     (host217-37-"
# spam -- msg: "++++++++++++++++++++++++++++++++++++++++++++++++++"
# ham -- msg: "A POWERHOUSE GIFTING PROGRAM You Don't Want To Mis"
# spam -- msg: "; Fri, 30 Aug 2002 11:35:38 +0100
#
#
#
# ------=_NextP"
# spam -- msg: "Sent e-mail message
#
#
#
# Sent e-mail message
#
# SH"
# spam -- msg: "DEAR FRIEND,I AM MRS.  SESE-SEKO WIDOW OF LATE PRE"
# spam -- msg: "Dear Sir / Madam
#
#
#
# If you are fed up of being 'ri"
# spam -- msg: "<HTML>
#
# <HEAD>
#
# <TITLE>Fist Bang FPA</TITLE>
#
# <MET"
# spam -- msg: "iieo
#
# <html>
#
# <head>
#
# <title>Mortgage companies ma"
# spam -- msg: "=3C!DOCTYPE HTML PUBLIC =22-=2F=2FW3C=2F=2FDTD HTM"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# spam -- msg: "DEAR OPPORTUNITIES SEEKERS:
#
#
#
# I THOUGHT YOU JUST "
# spam -- msg: "; Tue, 17 Sep 2002 20:14:45 +0100
#
#     (8.9.3/8.9."
# spam -- msg: "As se
#
# en on NB
#
# C, CBS, and CN
#
# N, and even Opr
#
# "
# spam -- msg: "; Fri, 20 Sep 2002 04:47:17 +0100
#
#     [217.56.95."
# spam -- msg: "=20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# 5% =
#
# Guarantee"
# spam -- msg: "Dear Sir,
#
# With due respect and humility I write "
# spam -- msg: "Incredible Deals on Inkjet Cartridges!
#
#
#
# Our Pric"
# spam -- msg: "Me and my friends have this brand new idea, a Live"
# spam -- msg: "MR MARTIN FRANCIS
#
# ABIDJAN COTE DIVOIRE
#
# WEST AFRI"
# spam -- msg: " Would You Like to
#
#
#
#  Save
#
# up to
#
#
#
# 80%
#
#
#
#     "
# spam -- msg: "This is a Multipart MIME message. Since your mail "
# ham -- msg: "; Sat, 21 Sep 2002 02:20:48 +0100
#
#     (Postfix) w"
# spam -- msg: "=20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# ="
# spam -- msg: "Conferencing Made=
#
#  Easy
#
#
#
# Only
#
# 18 Cents
#
#  Per"
# spam -- msg: "<$B;v6H<T(B>
#
# $B;aL>(B:Vip-mail
#
# $BFMA3$N%a!<"
# spam -- msg: "DON'T MISS OUT ON AN AMAZING BUSINESS OPPORTUNITY "
# spam -- msg: "------=_NextPart_000_00A5_78C83A6B.A1543A16
#
#
#
# MzU"
# spam -- msg: "<html>
#
# <head>
#
#    <meta http-equiv=3D"Content-Typ"
# ham -- msg: "It was the Spring of 1979.
#
#
#
# I was just a tall,"
# ham -- msg: "; Fri, 6 Sep 2002 09:16:24 +0100
#
#     webnote.net "
# ham -- msg: "; Sun, 25 Aug 2002 20:29:27 +0100
#
#     (8.9.3/8.9."
# spam -- msg: "Lowest rates available for term life insurance! Ta"
# spam -- msg: "Simple,
#
#               Easy and FREE
#
#
#
# Have
#
#   "
# spam -- msg: "<html>
#
#
#
# <head>
#
# <meta http-equiv=3D"Content-Lang"
# spam -- msg: "GET HIGH...LEGALLY!
#
#
#
# IT REALLY WORKS!
#
#
#
#       P"
# spam -- msg: "<html>
#
# <head>
#
# </head>
#
# <center>
#
# <h1>
#
# <b><font "
# spam -- msg: "=================================
#
#
#
# Guaranteed to"
# ham -- msg: "; Tue, 17 Sep 2002 00:45:11 +0100
#
#     (8.9.3/8.9."
# spam -- msg: "<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Trans"
# spam -- msg: "Dear Partner to be,
#
#
#
# First, I must apologise to "
# spam -- msg: "<HTML>
#
# <HEAD>
#
# </HEAD>
#
# <BODY>
#
# <FONT SIZE=3D"4">"
# spam -- msg: "<HTML><HEAD><TITLE>MILFhunter</TITLE>
#
# <META http-"
# spam -- msg: "<html>
#
#
#
# <head>
#
# <meta http-equiv="Content-Type" "
# spam -- msg: "Â Newsletter
#
#
#
# Discover Tomorrow's WinnersÂ
#
#
#
# F"
# ham -- msg: "; Wed, 4 Sep 2002 22:29:03 +0100
#
#     (Postfix) wi"
# spam -- msg: "5, Meridian East
#
# Leicester LE3 2WZ
#
# Leicester Ci"
# spam -- msg: "*** FREE BONUS OFFER - SEE BELOW ***
#
#
#
# We can sup"
# ham -- msg: "
#
#
#
#                   Welcome to "Ghetto" America"
# spam -- msg: "There is NO stumbling on to it!
#
#
#
# The greatest w"
# spam -- msg: "Whiter teeth and a brighter smile are just a click"
# spam -- msg: "1) Fight The Risk of Cancer!
#
# http://www.adclick.w"
# spam -- msg: "*****Write down*****
#
#
#
#
#
# Hello ,
#
#
#
#
#
# It is time "
# spam -- msg: "1) Fight The Risk of Cancer!
#
# http://www.adclick.w"
# spam -- msg: "This message is in MIME format. Since your mail re"
# spam -- msg: "++++++++++++++++++++++++++++++++++++++++++++++++++"
# spam -- msg: "=20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# A.M. Best =
#
# Co"
# spam -- msg: "Everybody gets paid.  No recruiting required.
#
#
#
# J"
# spam -- msg: "<html>
#
# <head>
#
# </head>
#
# <body>
#
#
#
# <center>
#
# <font"
# ham -- msg: "================This Is Definitely the Answer We A"
# spam -- msg: "This is a multipart MIME message.
#
#
#
# --= Multipart"
# spam -- msg: "Protect your financial well-being.
#
# Purchase an Ex"
# spam -- msg: "
#
# Dear Sir or Madam
#
#
#
# In the past you have reques"
# spam -- msg: "<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transi"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# ham -- msg: "; Sat, 24 Aug 2002 02:24:32 +0100
#
#     VAA15757; F"
# spam -- msg: "<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transi"
# spam -- msg: "------=_NextPart_000_00D1_61B37D4A.A0476B56
#
# Conte"
# spam -- msg: "ATTENTION:
#
#             This is a MUST for
#
# ALL
#
# "
# spam -- msg: "1) Fight The Risk of Cancer!
#
# http://www.adclick.w"
# ham -- msg: "; Fri, 6 Sep 2002 10:59:57 +0100
#
#     webnote.net "
# spam -- msg: "<html>
#
#
#
# <head>
#
# <meta http-equiv=3D"Content-Lang"
# spam -- msg: "--Boundary_(ID_57z4OPjIWZtVBINVV279ZQ)
#
#
#
# GET FREE"
# ham -- msg: "; Wed, 18 Sep 2002 17:14:55 +0100
#
#     [200.206.14"
# spam -- msg: "You can live a life o=
#
# f luxury
#
# only if you wor"
# spam -- msg: "As seen on NBC, CBS, CNN, and even Oprah! The heal"
# ham -- msg: "Email marketing works!  There's no way around it.
# "
# spam -- msg: "Wind up your mates today! Please visit http://ukpr"
# ham -- msg: "Dear Friends,
#
#
#
# The online content business is do"
# spam -- msg: "DEAR FRIEND,I AM MRS.  SESE-SEKO WIDOW OF LATE PRE"
# ham -- msg: "; Fri, 6 Sep 2002 10:29:52 +0100
#
#     (8.9.3/8.9.3"
# spam -- msg: "<html><head>
#
# <title>Congratulations! You Get a Fr"
# spam -- msg: "This is a Multipart MIME message. Since your mail "
# spam -- msg: "--===_SecAtt_000_1fheucnqggtggp
#
#
#
# URGENT PRIVATE "
# ham -- msg: "; Sat, 31 Aug 2002 17:11:05 +0100
#
#     Sat, 31 Aug"
# spam -- msg: "With DVDCopyPlus
#
#           and PowerCDR5.0 you c"
# spam -- msg: "On January 1st 2002, the European countries began
# "
# ham -- msg: "; Wed, 11 Sep 2002 12:06:05 +0100
#
#     (8.9.3/8.9."
# ham -- msg: "; Fri, 30 Aug 2002 22:04:57 +0100
#
#     (StyleZice@"
# spam -- msg: "If This Flyer does not appear correctly and/or ima"
# spam -- msg: "<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transi"
# spam -- msg: "; Wed, 28 Aug 2002 08:11:35 +0100
#
#
#
#              "
# spam -- msg: "HTML>
#
# <HEAD>
#
# <TITLE></TITLE>
#
# </HEAD>
#
# <BODY bgc"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# spam -- msg: "------=_NextPart_000_00C5_44B43D7A.C5027E65
#
#
#
# QVR"
# spam -- msg: "PGh0bWw+DQo8aGVhZD4NCjxtZXRhIGh0dHAtZXF1aXY9IkNvbn"
# spam -- msg: "<html>
#
# <head>
#
# <meta http-equiv=3D"Content-Type" "
# spam -- msg: "Copy DVD Mov=
#
# ies?
#
#
#
# Yes!  Copy and burn your ow"
# spam -- msg: "This message is in MIME format. Since your mail re"
# spam -- msg: "1) Fight The Risk of Cancer!
#
# http://www.adclick.w"
# spam -- msg: "<html>
#
#
#
#
#
#
#
# <body>
#
#
#
# <div align=3D"left">
#
#   <t"
# spam -- msg: "Dear zzzz =2C
#
#
#
# =3CBODY bgColor=3D#ffccff=3E
#
# =3C"
# spam -- msg: "------=_NextPart_000_00E2_80E42E6E.B7623D35
#
# Conte"
# ham -- msg: "; Fri, 23 Aug 2002 23:33:07 +0100
#
#     mail1.caram"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# ham -- msg: "            eBay Marketing e-Course...
#
#
#
#         "
# spam -- msg: "1) Claim Your $25 Kmart Gift Card
#
# http://www.adcl"
# spam -- msg: "<html>
#
# <head>
#
# <title>Digital Publishing Tools - "
# spam -- msg: "------=_NextPart_000_00E4_17A73C2D.E7104E07
#
# Conte"
# spam -- msg: "###################################
#
#
#
#   FREE Adul"
# spam -- msg: "Free Introductory Offer!
#
#
#
# Mother Nature's own al"
# spam -- msg: "<HTML>
#
# <TABLE id=AutoNumber2 style="BORDER-COLLAP"
# spam -- msg: "This is a Multipart MIME message. Since your mail "
# spam -- msg: "ATTENTION:
#
#             This is a MUST for
#
# ALL
#
# "
# spam -- msg: "; Sat, 21 Sep 2002 17:34:37 +0100
#
#     (8.9.3/8.9."
# spam -- msg: "<html>
#
#
#
# <head>
#
# <title>Classic Wines</title>
#
# </"
# spam -- msg: "Targeted email marketing works!  There's no way ar"
# ham -- msg: ""
# ham -- msg: "Would you like to know what the Powerball Winning "
# spam -- msg: "Opportunity is knocking. Why?
#
#
#
# Because mortgage "
# spam -- msg: "=20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# Fixed and index"
# spam -- msg: "New Account For: zzzz@spamassassin.taint.org
#
# ####"
# ham -- msg: "; Thu, 5 Sep 2002 01:02:05 +0100
#
#     (8.9.3/8.9.3"
# spam -- msg: "<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transi"
# ham -- msg: "ATTN:SIR/MADAN
#
#
#
#                           "
# spam -- msg: "Lowest rates available for term life insurance! Ta"
# ham -- msg: "; Fri, 20 Sep 2002 10:51:15 +0100
#
#     (8.9.3/8.9."
# spam -- msg: "<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transi"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# spam -- msg: "++++++++++++++++++++++++++++++++++++++++++++++++++"
# spam -- msg: "" Qualify for
#
# at least
#
#  $25,000 in free
#
# grants"
# spam -- msg: "<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2//EN">
# "
# spam -- msg: "Market Internet Access
#
#
#
# No Investment Needed
#
# "
# spam -- msg: "HABERDAR.COM - HABER VE MEDYA PORTALI
#
# Artýk tüm h"
# ham -- msg: "Hi Job Seeker,
#
#
#
# When you create a FREE My Net-Te"
# spam -- msg: "<html>
#
# <head>
#
# </head>
#
# <center>
#
# <h1>
#
# <b><font "
# spam -- msg: "Legal Teen XXX Hardcore
#
# 4 FREE
#
#
#
# Boy was Gauge s"
# ham -- msg: "Hi,
#
#
#
# I'm a college dropout.  I work about two ho"
# spam -- msg: "--374035298.1030784379296.JavaMail.SYSTEM.emaserve"
# spam -- msg: "<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transi"
# ham -- msg: "5, Meridian East
#
# Leicester LE3 2WZ
#
# Leicester Ci"
# ham -- msg: "THE ULTIMATE WAY TO WORK FROM HOME
#
# THE BEST MONE"
# spam -- msg: "Suppliers of Computers, Printers, etc. & Consumabl"
# spam -- msg: "=20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# Eliminates all "
# spam -- msg: "Publish Like a Professional with Digital Publishin"
# spam -- msg: "------=_NextPart_000_00E3_67D27D5C.B1748B87
#
#
#
# R2V"
# spam -- msg: "We guarantee you signups before you ever pay
#
# a pe"
# spam -- msg: "1) Fight The Risk of Cancer!
#
# http://www.adclick.w"
# spam -- msg: "Dear ilug@linux.ie
#
#
#
# Life Partners are life insu"
# spam -- msg: "<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2//EN">
# "
# spam -- msg: "chdvd.com from Columbia House
#
#
#
# The Columbia Hous"
# spam -- msg: "When America's top companies compete for your busi"
# spam -- msg: "They Intimidate you...They Humiliate you...
#
#
#
# And"
# spam -- msg: "I am Mr.IKE EJOH. Bank Manager of Diamond Bank of "
# spam -- msg: "------=_NextPart_000_00C6_24D75C3A.C0588C07
#
# Conte"
# spam -- msg: "You are receiving this mailing because you are a
#
# "
# spam -- msg: "<html>
#
# <TABLE id=AutoNumber2 style="BORDER-COLLAP"
# ham -- msg: "78l95"
# spam -- msg: "REGISTER DOMAINS FOR JUST $14.95
#
#
#
#
#
# The new doma"
# spam -- msg: "<html><body onload="window.open('http://202.101.16"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# spam -- msg: "Hallo,
#
#
#
# Wir haben uns schon ziemlich lange nicht"
# spam -- msg: "--0-1118764524-1030968705=:44128
#
# Content-Type: te"
# spam -- msg: "Life
#
#                                 can change i"
# spam -- msg: "Dear Sir or Madam
#
#
#
# In the past you have requeste"
# spam -- msg: "<$B;v6H<T(B>
#
# $B;aL>(B:Vip-mail
#
# $BFMA3$N%a!<"
# spam -- msg: "<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transi"
# spam -- msg: "1) Lose 22.5lbs in 3 weeks!
#
# Flush Fat Away Foreve"
# spam -- msg: "on Toners,Â
#
#
#
# Inkjets, FAX, and Thermal Replenis"
# spam -- msg: "<body topmargin=0 leftmargin=0><TABLE cellSpacing="
# spam -- msg: "NEWSLETTER COACHINVEST  SEPTEMBRE 2002
#
#
#
# Coach"
# spam -- msg: "<HTML><HEAD><TITLE></TITLE><META http-equiv=3D=22C"
# spam -- msg: "Dear Sir / Madam
#
#
#
# If you are fed up of being 'ri"
# spam -- msg: "Help wanted.  We are a 14 year old fortune 500 com"
# spam -- msg: "------=_NextPart_000_00E2_83D00E6B.E2024A14
#
# Conte"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# spam -- msg: "Me and my friends have this brand new idea, a Live"
# ham -- msg: "; Fri, 23 Aug 2002 08:41:13 +0100
#
#     (8.9.3/8.9."
# spam -- msg: "1) Need a Credit Card? We'll get One for You!
#
# htt"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# spam -- msg: "<HTML><HEAD><TITLE>Lowest Rate Services</TITLE>
#
# <"
# spam -- msg: "<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transi"
# ham -- msg: "
#
# >>From the desk of: DR. SAMUEL EBOKA.
#
# Tel No: Y"
# spam -- msg: "O
#
# ver
#
# $9 Billion
#
#  i=
#
# n merchandise
#
#         "
# spam -- msg: "------=_NextPart_000_00A3_00E67D7E.B8560D80
#
#
#
# MzY"
# spam -- msg: "<html><xbody>
#
# <hr width = "100%">
#
# <center><font "
# ham -- msg: "Below is the result of your feedback form.  It was"
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# spam -- msg: "--TEP-2108411027.1463792894.1027038601
#
# Content-Ty"
# spam -- msg: "
#
# Dear Sir or Madam
#
#
#
# In the past you have reques"
# ham -- msg: "
#
#                          Foreword
#
#
#
# After thirt"
# spam -- msg: "<html>
#
# <head>
#
# <title>Digital Publishing Tools - "
# spam -- msg: "=20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# =20
#
#
#
# Male 64 "
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# ham -- msg: "Dear Sir,
#
#
#
# I am Dr James Alabi, the chairman of "
# spam -- msg: "------=_NextPart_000_002B_83A1E322.4D8B344B
#
# Conte"
# ham -- msg: "; Mon, 9 Sep 2002 22:17:09 +0100
#
#     (8.9.3/8.9.3"
# spam -- msg: "--1189366250.1031600041421.JavaMail.SYSTEM.emaserv"
# spam -- msg: "Everybody gets paid.  No recruiting required.
#
#
#
# J"
# spam -- msg: "; Tue, 8 Oct 2002 10:58:16 +0100
#
#     (8.9.3/8.9.3"
# ham -- msg: "This system is quite simply
#
# the most logical, ope"
# spam -- msg: "__________________________________________________"
# spam -- msg: "<HTML>
#
# <HEAD>
#
# </HEAD>
#
# <BODY>
#
# VIAGRA, XENICAL, "
# ham -- msg: "; Tue, 3 Dec 2002 14:11:11 GMT
#
#     [67.64.113.55]"
# spam -- msg: "<HTML>
#
# <head>
#
# <META HTTP-EQUIV="Content-Type" CO"
# spam -- msg: "<p>Dear user,</p>
#
# <p>CyberAge Dating Club is cont"
# spam -- msg: "PROFESSIONAL, EFFECTIVE DEBT COLLECTION SERVICES A"
# spam -- msg: "<FONT face=3D"MS Sans Serif">
#
# <FONT size=3D2> <ht"
# spam -- msg: "<html>
#
# <head>
#
# <title>FREESTORES - MAKE MONEY GIV"
# spam -- msg: "<html>
#
# <head>
#
# </head>
#
# <body>
#
#
#
# <center>
#
# <font"
# spam -- msg: "Take Control of Your Computer
#
#     With This Top-"
# spam -- msg: "; Fri, 6 Sep 2002 09:18:26 +0100
#
#     webnote.net "
# spam -- msg: "
#
# ÐÏà¡±á Worldwide*
#
# Great Restaurants, Shopping"
# spam -- msg: "$19.95 and up!  Buy cartons of cigarettes wholesal"
# spam -- msg: "<html>
#
# <head>
#
# <title>PoliceAuctions.com</title>
# "
# spam -- msg: "This is a multi-part message in MIME format.
#
#
#
# --"
# ham -- msg: "=FF=
#
# FFFFA9
#
# Copyright 2002 - All rights reserved"
# spam -- msg: "Ou Wei Lighting, Nights Will Be Lightening!!!
#
#
#
#  "
# spam -- msg: "------=_NextPart_000_00E3_44B55B3D.C1001A02
#
#
#
# MDQ"
# spam -- msg: "<HTML><HEAD><TITLE>MILFhunter</TITLE>
#
# <META http-"
# spam -- msg: "ààªÍ¶¯ÄÔÇ¤ªäêé
#
# µ¶ÝÆààÌR{"
# spam -- msg: "1) Fight The Risk of Cancer!
#
# http://www.adclick.w"
# ham -- msg: "Hiya, I always seem to get errors when I do an "ap"
# ham -- msg: "; Thu, 12 Sep 2002 06:05:54 -0700
#
#     (CommuniGat"
# ham -- msg: "; Mon, 4 Feb 2002 13:02:22 GMT
#
#     auth02.nl.egwn"
# ham -- msg: "; Wed, 25 Sep 2002 09:00:27 +0100
#
#
#
# There are a f"
# ham -- msg: "URL: http://www.newsisfree.com/click/-1,8390121,17"
# ham -- msg: "> Gary Lawrence Murphy wrote:
#
# > >and say hello to"
# ham -- msg: "There is a whitelist RBL now!  Ironport's Bonded S"
# ham -- msg: "; Fri, 20 Sep 2002 14:05:46 -0700
#
#     sunserver.s"
# ham -- msg: "; Mon, 30 Sep 2002 09:01:47 +0100
#
#
#
# You are not s"
# ham -- msg: "[Jeremy]
#
# > The total collections are 1100 message"
# ham -- msg: "
#
# Wow, if they put a VRML front end on it it would"
# ham -- msg: "On Thu, 19 Sep 2002, Bill Stoddard wrote:
#
# --]How "
# ham -- msg: ">>>>> "M" == Mike Masnick <mike@techdirt.com> writ"
# ham -- msg: "
#
# Over on Arstechnica (www.arstechnica.com) I saw "
# ham -- msg: "URL: http://www.newsisfree.com/click/-4,8512678,14"
# ham -- msg: "On 28 Aug 2002, Daniel Quinlan wrote:
#
#
#
# > Dan Koh"
# ham -- msg: "On 04 Oct 2002 22:25:31 -0400, QuaffA Pint <quaffa"
# ham -- msg: "see my first line: I READ THE LINKS.  brickbats.  "
# ham -- msg: "--]
#
# --] Anyone heard of this law before?
#
#
#
# Back "
# ham -- msg: "URL: http://www.newsisfree.com/click/-5,8062538,14"
# ham -- msg: "use Perl Daily Newsletter
#
#
#
# In this issue:
#
#     *"
# ham -- msg: "; Tue, 10 Sep 2002 03:02:53 +0100
#
#     listman.red"
# ham -- msg: "; Fri, 4 Oct 2002 11:26:48 +0100
#
#     (8.11.6/8.11"
# ham -- msg: "I think that when considering deployment, a soluti"
# ham -- msg: "On Saturday 28 September 2002 04:37 pm, you strugg"
# ham -- msg: "Here's a weird and wacky problem:
#
#
#
# I'm currently"
# ham -- msg: "This is a multi-part message in MIME format.
#
# ----"
# ham -- msg: "On Fri, 13 Sep 2002, Tony L. Svanstrom mused:
#
# > O"
# ham -- msg: "URL: http://www.mozillazine.org/weblogs/hyatt/#854"
# ham -- msg: "And the ever popular...
#
#
#
#
#
# Or bring a baby,
#
# Pro"
# ham -- msg: "URL: http://www.aaronsw.com/weblog/000614
#
# Date: 2"
# ham -- msg: "On Thu, 2002-08-29 at 01:50, Matthias Saou wrote:
# "
# ham -- msg: "> US listers will recognise Damian Lewis as Lieute"
# ham -- msg: "use Perl Daily Newsletter
#
#
#
# In this issue:
#
#     *"
# ham -- msg: "
#
# Valdis.Kletnieks@vt.edu said:
#
# > I checked on a "
# ham -- msg: "On Wed, 2002-08-28 at 13:57, Michael Clark wrote:
# "
# ham -- msg: "; Sat, 14 Sep 2002 00:32:39 +0100
#
#     listman.red"
# ham -- msg: "URL: http://www.aaronsw.com/weblog/000611
#
# Date: 2"
# ham -- msg: "; Tue, 27 Aug 2002 19:17:01 +0100
#
#     (8.9.3/8.9."
# ham -- msg: "On 14:22 29 Aug 2002, Matthias Saou <matthias@egwn"
# ham -- msg: "Once upon a time, Lance wrote :
#
#
#
# > Ok, I got ALS"
# ham -- msg: "URL: http://diveintomark.org/archives/2002/10/02.h"
# ham -- msg: "
#
# Ahhhh Dave Winer..Seems like only yesterday fork"
# ham -- msg: "URL: http://www.newsisfree.com/click/-2,8666353,21"
# ham -- msg: "; Thu, 3 Oct 2002 09:01:31 +0100
#
#
#
# Rob "Pringles "
# ham -- msg: "Once upon a time, Gary wrote :
#
#
#
# > On Wed, Oct 02"
# ham -- msg: "URL: http://www.newsisfree.com/click/-1,8408636,17"
# ham -- msg: "URL: http://boingboing.net/#85481649
#
# Date: Not su"
# ham -- msg: "; Sat, 7 Sep 2002 05:41:08 +0000
#
#
#
# On Friday 06 S"
# ham -- msg: "
#
# http://www.phc.mpr.org/posthost/index.shtml
#
#
#
# D"
# ham -- msg: "Is there any way to customise the folder table of "
# ham -- msg: "URL: http://scriptingnews.userland.com/backissues/"
# ham -- msg: "URL: http://diveintomark.org/archives/2002/09/30.h"
# ham -- msg: "URL: http://www.newsisfree.com/click/-2,8182249,14"
# ham -- msg: "
#
# Vipul Ved Prakash said:
#
#
#
# > Are there any sugge"
# ham -- msg: "funny. i read it as green = red, as in accounting,"
# ham -- msg: "URL: http://www.askbjoernhansen.com/archives/2002/"
# ham -- msg: "Does anyone here know if the Computational Recreat"
# ham -- msg: "; Fri, 6 Sep 2002 10:57:35 +0100
#
#     [66.38.151.2"
# ham -- msg: "; Tue, 24 Sep 2002 18:05:29 -0700 (PDT)
#
#     venus"
# ham -- msg: "
#
# On Mon, 09 Sep 2002 12:05:55 PDT,
#
# 	Rick Baartma"
# ham -- msg: "I recently transfered my exmh setup to a new syste"
# ham -- msg: "; Thu, 29 Aug 2002 05:37:30 -0700
#
#     panoramix.v"
# ham -- msg: "; Fri, 6 Sep 2002 10:54:42 +0100
#
#     by webnote.n"
# ham -- msg: "> Now for Benjamin, yea id love to have something "
# ham -- msg: "; Mon, 26 Aug 2002 08:33:35 -0700
#
#     [130.240.20"
# ham -- msg: ">>>>> "S" == Stephen D Williams <sdw@lig.net> writ"
# ham -- msg: "; Fri, 6 Sep 2002 10:39:44 +0100
#
#     [216.136.171"
# ham -- msg: "> As I've said before, American
#
# > Indian Reservat"
# ham -- msg: "; Thu, 26 Sep 2002 16:27:49 +0100
#
#
#
# Tony Davis wr"
# ham -- msg: "; Fri, 4 Oct 2002 09:00:05 +0100
#
#
#
# So, d'ya remem"
# ham -- msg: "URL: http://diveintomark.org/archives/2002/10/02.h"
# ham -- msg: "
#
# --huq684BweRXVnRxX
#
# Content-Type: text/plain; ch"
# ham -- msg: "URL: http://diveintomark.org/archives/2002/10/03.h"
# ham -- msg: "URL: http://scriptingnews.userland.com/backissues/"
# ham -- msg: "On Wed, 28 Aug 2002, Matthew Cline wrote:
#
#
#
# > The"
# ham -- msg: "
#
#
#
# > -----Original Message-----
#
# > From: Aherne P"
# ham -- msg: "; Sun, 22 Sep 2002 00:57:24 -0700 (PDT)
#
#     22 Se"
# ham -- msg: "; Mon,  9 Sep 2002 10:37:48 -0700 (PDT)
#
#     mayna"
# ham -- msg: "; Tue, 1 Oct 2002 03:00:03 +0100
#
#     (Exim 3.35 #"
# ham -- msg: "URL: http://www.newsisfree.com/click/-2,8664946,14"
# ham -- msg: "; Fri, 27 Sep 2002 23:20:01 -0700 (PDT)
#
#     [64.1"
# ham -- msg: "Thanks for this information.  I gave Alsa a try, c"
# ham -- msg: "I'd like to claim the parenthood of desktop web se"
# ham -- msg: "URL: http://www.newsisfree.com/click/-1,8412855,14"
# ham -- msg: "On Mon, 2 Sep 2002, Russell Turpin wrote:
#
#
#
# > Ada"
# ham -- msg: "  >> The false positive rate is 0-3%.  (Finally!  "
# ham -- msg: "URL: http://boingboing.net/#85541025
#
# Date: Not su"
# ham -- msg: "; Fri, 23 Aug 2002 07:21:59 +0100
#
#     listman.red"
# ham -- msg: "; Mon, 26 Aug 2002 11:43:33 -0400
#
#     (EDT)
#
#     "
# ham -- msg: "Justin Mason writes:
#
# > Has anyone figured out wha"
# ham -- msg: "URL: http://boingboing.net/#85513638
#
# Date: Not su"
# ham -- msg: "
#
# EL> On Sun, 8 Sep 2002, CDale wrote:
#
#
#
# >> I agr"
# ham -- msg: "URL: http://www.newsisfree.com/click/-2,8668042,14"
# ham -- msg: "    >> Before we get too far down this road, what "
# ham -- msg: "Forgive me for being a partially stupid end-user o"
# ham -- msg: "
#
#
#
# > For my part, I'd rather people didn't use Fo"
# ham -- msg: "Depends on how much over spending vs. how much (an"
# ham -- msg: "; Thu, 26 Sep 2002 09:01:31 +0100
#
#
#
# Ray Ozzie[1]:"
# ham -- msg: "
#
# ----- Original Message -----
#
# From: "Scott Wood""
# ham -- msg: "; Fri,  6 Sep 2002 02:59:19 -0700 (PDT)
#
#     6 Sep"
# ham -- msg: "I received a spam email that had apparently forged"
# ham -- msg: "URL: http://www.newsisfree.com/click/-2,8417753,17"
# ham -- msg: "I'm after a recipe for using Razor with Sendmail. "
# ham -- msg: "; Wed, 18 Sep 2002 18:27:07 -0700 (PDT)
#
#     helo="
# ham -- msg: "    This is the binary pickle of my classifier aft"
# ham -- msg: "; Sat, 21 Sep 2002 01:07:18 -0700 (PDT)
#
#     smtp1"
# ham -- msg: ""Free trade and free markets have proven their abi"
# ham -- msg: "Update of /cvsroot/spamassassin/spamassassin
#
# In d"
# ham -- msg: ">>>>> "E" == Eirikur Hallgrimsson <eh@mad.scientis"
# ham -- msg: "
#
# ----- Original Message -----
#
# From: "R. A. Hetti"
# ham -- msg: "URL: http://boingboing.net/#85534853
#
# Date: Not su"
# ham -- msg: "; Thu, 12 Sep 2002 03:21:43 +0100
#
#     listman.red"
# ham -- msg: "
#
# "Craig R.Hughes" said:
#
#
#
# > The GA run on the cu"
# ham -- msg: "URL: http://www.newsisfree.com/click/-4,8723997,21"
# ham -- msg: "URL: http://boingboing.net/#85541081
#
# Date: Not su"
# ham -- msg: "On Sat, 24 Aug 2002 11:07:00 -0700, "John Hall"
#
# "
# ham -- msg: "On Mon, 09 Sep 2002 15:36:37 -0400
#
# Tom Reingold "
# ham -- msg: "Gary Lawrence Murphy wrote:
#
#
#
# >>>>>>"R" == R A He"
# ham -- msg: "
#
#
#
# > From: Stephen D. Williams [mailto:swilliams@"
# ham -- msg: "; Mon, 30 Sep 2002 09:01:48 +0100
#
#
#
# This Monkey S"
# ham -- msg: "hdparm -d1 /dev/hdc says Operation not Permitted.
# "
# ham -- msg: "jm@jmason.org (Justin Mason) writes:
#
#
#
# > Actually"
# ham -- msg: "; Wed, 11 Sep 2002 20:18:09 +0100
#
#     listman.red"
# ham -- msg: ">It seems good Ol' Uncle Dave is once again trying"
# ham -- msg: "right Mike,
#
#
#
# i will agree to disagree but i take"
# ham -- msg: "; Mon, 26 Aug 2002 19:40:04 +0100
#
#     (8.11.6/8.1"
# ham -- msg: "
#
# Is this old bits? It should be.
#
#
#
# I was browsin"
# ham -- msg: "Mark Derricutt wrote:
#
# > Never mind, there was som"
# ham -- msg: "Robert Harley writes:
#
# > >OK, then. Consider a pop"
# ham -- msg: "--- In forteana@y..., "Webmaster"
#
#  wrote:
#
# >Righ"
# ham -- msg: "X-Habeas-Swe-1: winter into spring
#
# X-Habeas-Swe-2"
# ham -- msg: "URL: http://www.newsisfree.com/click/-0,8357899,21"
# ham -- msg: "Gary's news service at teledyn.com has an article "
# ham -- msg: "URL: http://scriptingnews.userland.com/backissues/"
# ham -- msg: "
#
# --]> A Green once said that if the Spotted Owl h"
# ham -- msg: ">JUST as the pyramids of Egypt were built in honou"
# ham -- msg: "; Thu, 10 Oct 2002 09:04:23 +0100
#
#
#
# My Tivo has b"
# ham -- msg: "; Tue, 1 Oct 2002 09:01:22 +0100
#
#     highway. Hil"
# ham -- msg: "; Sun, 29 Sep 2002 09:01:17 +0100
#
#
#
# It wasn't jus"
# ham -- msg: "URL: http://boingboing.net/#85516333
#
# Date: Not su"
# ham -- msg: "; Sat, 5 Oct 2002 09:00:56 +0100
#
#
#
# A collision is"
# ham -- msg: "Hi,
#
#
#
# Just the kind of announce I make once in a "
# ham -- msg: "Hi all.
#
# Does anyone know how to set up dual keybo"
# ham -- msg: "; Mon, 30 Sep 2002 09:00:33 +0100
#
#
#
# I've been in "
# ham -- msg: "; Thu, 10 Oct 2002 09:00:03 +0100
#
#
#
# It's confirme"
# ham -- msg: "Just to put the germano-Indian fascination in cont"
# ham -- msg: "URL: http://boingboing.net/#85524777
#
# Date: Not su"
# ham -- msg: "The Times
#
#
#
#
#
#  September 06, 2002
#
#
#
#  Hitler-s"
# ham -- msg: "Begin forwarded message:
#
#
#
# > From: Ian Andrew Bel"
# ham -- msg: "Understand, not enough caffeine absorbed yet this "
# ham -- msg: "I finally let go of my Irix Magic desktop and wind"
# ham -- msg: "Once upon a time, Ralf wrote :
#
#
#
# > Are there any "
# ham -- msg: "
#
# > On Thu, Sep 19, 2002 at 11:11:47AM -0400, Bill"
# ham -- msg: "http://www.techcentralstation.com/1051/printer.jsp"
# ham -- msg: "http://www.bbc.co.uk/radio1/alt/nireland/ni_team.s"
# ham -- msg: "This is an automated response to a message you hav"
# ham -- msg: "; Fri, 13 Sep 2002 12:37:33 -0700 (PDT)
#
#     (Inte"
# ham -- msg: "Hah.  I guess she doesn't want everyone to know ab"
# ham -- msg: "So do you know my public key?  Does the guy who wa"
# ham -- msg: "URL: http://www.newsisfree.com/click/-5,8305902,17"
# ham -- msg: "Actually this is output from an old java program c"
# ham -- msg: "Hello fork,
#
#
#
#   So they have Aaron Schwartz on NP"
# ham -- msg: "; Wed, 9 Oct 2002 09:00:35 +0100
#
#
#
# [IMG: http://b"
# ham -- msg: "X-Habeas-Swe-1: winter into spring
#
# X-Habeas-Swe-2"
# ham -- msg: "What I understood was that the activists on the tr"
# ham -- msg: "> "the historical record", by which you mean *huma"
# ham -- msg: "URL: http://www.newsisfree.com/click/-5,8561544,14"
# ham -- msg: "I know this is simple but do you have /usr/src/lin"
# ham -- msg: "
#
# --J2SCkAp4GZ/dPZZf
#
# Content-Type: text/plain; ch"
# ham -- msg: "URL: http://www.newsisfree.com/click/-1,8390120,17"
# ham -- msg: "On Tuesday 27 August 2002 19:26 CET Leroy B. wrote"
# ham -- msg: "
#
# So much for carnivore ;)
#
#
#
# --
#
# Gary Lawrence M"
# ham -- msg: "[Tim]
#
# > My tests train on about 7,000 msgs, and a"
# ham -- msg: "URL: http://www.mozillazine.org/weblogs/hyatt/#853"
# ham -- msg: "URL: http://www.newsisfree.com/click/-4,8279860,21"
# ham -- msg: "; Sat, 5 Oct 2002 09:00:30 +0100
#
#
#
# Doom has been "
# ham -- msg: "
#
# --Hlh2aiwFLCZwGcpw
#
# Content-Type: text/plain; ch"
# ham -- msg: "; Mon, 30 Sep 2002 22:07:23 +0100
#
#     (8.11.6/8.1"
# ham -- msg: "In addition, one bit of anecdotal evidence from a "
# ham -- msg: "URL: http://www.newsisfree.com/click/-1,8622117,21"
# ham -- msg: "; Fri, 4 Oct 2002 09:00:51 +0100
#
#
#
# A material tha"
# ham -- msg: "The Electronic Telegraph
#
#
#
#  Six arrested for atta"
# ham -- msg: "I think it's fine, in general, just so long as no-"
# ham -- msg: "jm@jmason.org (Justin Mason) writes:
#
#
#
# >>>   DATE"
# ham -- msg: "(This list is sponsored by Ironclad Networks http:"
# ham -- msg: "What's the trick again to have it default to showi"
# ham -- msg: "Chuck Murcko wrote:
#
#
#
# > Heh, ten years ago saying"
# ham -- msg: "--==_Exmh_1521948024P
#
# Content-Type: text/plain; c"
# ham -- msg: "; Thu, 3 Oct 2002 00:37:36 +0100
#
#     Wed,  2 Oct "
# ham -- msg: "URL: http://www.newsisfree.com/click/-3,8251864,14"
# ham -- msg: "; Tue, 24 Sep 2002 09:00:03 +0100
#
#
#
# Trust me when"
# ham -- msg: "
#
# This just blew my mind:
#
# http://www.earthviewer."
# ham -- msg: "At 05:38 PM 9/30/2002 +0200, Eugen Leitl wrote:
#
#
# "
# ham -- msg: "; Wed, 2 Oct 2002 09:02:51 +0100
#
#
#
# *Talk:* Join t"
# ham -- msg: "; Tue, 24 Sep 2002 19:14:51 +0100
#
#     listman.red"
# ham -- msg: "URL: http://www.newsisfree.com/click/-4,8274140,17"
# ham -- msg: "URL: http://www.mozillazine.org/weblogs/hyatt/#854"
# ham -- msg: "On Sun, 1 Sep 2002, Joseph S. Barrera III wrote:
#
# "
# ham -- msg: "; Sat, 5 Oct 2002 14:24:42 +0100
#
#     (8.11.6/8.11"
# ham -- msg: "http://beast.gtk.org
#
#
#
# There's a realy nasty shor"
# ham -- msg: "; Tue, 3 Sep 2002 21:24:01 +0100
#
#     with ESMTP i"
# ham -- msg: "; Sun, 15 Sep 2002 13:31:53
#
#     -0700
#
#     [130.2"
# ham -- msg: "
#
# Bob Sully said:
#
#
#
# > Spamassassin (2.30) has bee"
# ham -- msg: "; Tue, 27 Aug 2002 23:52:06 -0400
#
#     forteana-ow"
# ham -- msg: "I call PacBell/SBC every two or three months about"
# ham -- msg: "This is something new, or at least new to me:
#
#
#
# "
# ham -- msg: "; Tue, 8 Oct 2002 20:48:26 +0000
#
#
#
# http://reuters"
# ham -- msg: "; Fri, 4 Oct 2002 08:07:05 +0100
#
#     (8.11.6/8.11"
# ham -- msg: ">>>>> "J" == James Rogers <jamesr@best.com> writes"
# ham -- msg: "URL: http://www.newsisfree.com/click/-3,8688975,21"
# ham -- msg: "
#
# >>>>> "TP" == Tim Peters <tim.one@comcast.net> w"
# ham -- msg: "On Thu, Aug 22, 2002 at 10:58:34PM +0200, Robert H"
# ham -- msg: "; Tue, 8 Oct 2002 09:01:21 +0100
#
#
#
# The latest "Re"
# ham -- msg: ">>From the Hoax or Hack Dept:
#
# Digital Needle - A "
# ham -- msg: "URL: http://www.newsisfree.com/click/-4,8259315,17"
# ham -- msg: "; Wed, 2 Oct 2002 21:50:04 +0100
#
#     (8.11.6/8.11"
# ham -- msg: "URL: http://www.newsisfree.com/click/-2,8674045,21"
# ham -- msg: "; Thu, 26 Sep 2002 09:01:29 +0100
#
#     to be of a
# "
# ham -- msg: "
#
# ----- Original Message -----
#
# From: "John Hall" "
# ham -- msg: "; Fri, 1 Feb 2002 09:34:19 GMT
#
#     auth02.nl.egwn"
# ham -- msg: "I have no idea.  I made up the name.  Thanks for t"
# ham -- msg: "; Wed, 4 Dec 2002 11:46:37 GMT
#
#     (Postfix) with"
# ham -- msg: "Razor won't filter empty emails. What version of t"
# ham -- msg: "It will function as a router if that is what you w"
# ham -- msg: "BlogStart:
#
#
#
# **Dublin**: something from the arch"
# ham -- msg: "I recently stumbled across the contents of the jou"
# ham -- msg: "-----BEGIN PGP SIGNED MESSAGE-----
#
# Hash: SHA1
#
#
#
# "
# ham -- msg: "So, last night around 5:30AM I'm woken up by a lou"
# ham -- msg: "Read the article.  I'm afraid I don't understand h"
# ham -- msg: "On Thu, 22 Aug 2002 the voices made Justin Mason w"
# ham -- msg: "On Tue, 2002-09-17 at 11:16, Gary Lawrence Murphy "
# ham -- msg: "URL: http://www.newsisfree.com/click/-3,8457381,21"
# ham -- msg: "Well, I know a guy that split up from her that wro"
# ham -- msg: "cdale is a double chocolate chip macadamia to my v"
# ham -- msg: "; Thu, 26 Sep 2002 16:11:22 +0100
#
#
#
# Morten Freder"
# ham -- msg: "
#
# >>>>> "NS" == Neil Schemenauer <nas@python.ca> w"
# ham -- msg: "; Sun, 6 Oct 2002 09:00:08 +0100
#
#
#
# I guess it's t"
# ham -- msg: "URL: http://www.askbjoernhansen.com/archives/2002/"
# ham -- msg: "URL: http://www.newsisfree.com/click/215,0,215/
#
# D"
# ham -- msg: "; Mon, 2 Sep 2002 12:07:02 +0100
#
#     (8.9.3/8.9.3"
# ham -- msg: "; Wed, 2 Oct 2002 08:49:34 +0100
#
#     (8.11.6/8.11"
# ham -- msg: "
#
# I wanted to get back to this but didn't have the"
# ham -- msg: "We met a family in our parent-baby group with a so"
# ham -- msg: "So, given the apparent commonality of these occura"
# ham -- msg: "
#
# > They weren't partitioned in any particular sch"
# ham -- msg: "Kind of interesting application of 'agent' technol"
# ham -- msg: "[Skip Montanaro]
#
# > After my latest cvs up, timtes"
# ham -- msg: "; Thu, 29 Aug 2002 20:52:10 +0100
#
#     (8.11.6/8.1"
# ham -- msg: ">Benoit claimed the prize for his size 14 feet. In"
# ham -- msg: "Adam Beberg writes:
#
# > On Tue, 3 Sep 2002, Kragen "
# ham -- msg: "I've been testing Razor, invoked from sendmail/pro"
# ham -- msg: ") by 192.220.76.165 (qmail-ldap-1.03) with SMTP fo"
# ham -- msg: "One of the most bizarre pages I've seen on the Web"
# ham -- msg: "The structure of the Internet has never
#
# been abou"
# ham -- msg: "On Tue, 10 Sep 2002 18:39:07 +0200
#
# Matthias Saou "
# ham -- msg: "URL: http://diveintomark.org/archives/2002/09/24.h"
# ham -- msg: "In a message dated: Thu, 22 Aug 2002 13:53:55 CDT
# "
# ham -- msg: "Robin Lynn Frank <rlfrank@paradigm-omega.com> writ"
# ham -- msg: "
#
#
#
# -----Original Message-----
#
#
#
# Subject: please "
# ham -- msg: "
#
# Not true on the choice part.
#
#
#
# After three week"
# ham -- msg: "; Mon, 2 Sep 2002 11:58:09 +0100
#
#     (8.9.3/8.9.3"
# ham -- msg: "   of "Tue, 17 Sep 2002 18:36:05 PDT."
#
#
#
# X-Habea"
# ham -- msg: "
#
# >>>>> "GW" == Greg Ward <gward@python.net> write"
# ham -- msg: "BTW, I've been thinking a little about the RPMs an"
# ham -- msg: "> Apols if this has been posted before:
#
# >
#
# > htt"
# ham -- msg: "Ham distribution for all runs:
#
# * = 1333 items
#
#   "
# ham -- msg: ""Adam L. Beberg" wrote:
#
# >
#
# > So, who has done RS"
# ham -- msg: "On 9/8/02 7:38 AM, "Gary Lawrence Murphy" <garym@c"
# ham -- msg: "MF> Here is a sample conversation on (MSN Messenge"
# ham -- msg: "URL: http://scriptingnews.userland.com/backissues/"
# ham -- msg: "URL: http://boingboing.net/#85524557
#
# Date: Not su"
# ham -- msg: "On Tue, 24 Sep 2002 ThosStew@aol.com wrote:
#
#
#
# --]"
# ham -- msg: "
#
# --9amGYk9869ThD9tj
#
# Content-Type: text/plain; ch"
# ham -- msg: "	"Mr. FoRK"
#
# ,
#
# ,
#
# 	"Digital Bearer Settlement L"
# ham -- msg: "I'm a new user (or about to be, hopefully) of SA b"
# ham -- msg: "On Tue, 27 Aug 2002 the voices made Jason R. Masta"
# ham -- msg: "URL: http://boingboing.net/#85524618
#
# Date: Not su"
# ham -- msg: "; Mon, 7 Oct 2002 09:35:26 +0100
#
#     (Postfix) wi"
# ham -- msg: "    Date:        Wed, 21 Aug 2002 10:40:39 -0500
#
# "
# ham -- msg: "Congrats, in the end...
#
# > "If they didn't have Ma"
# ham -- msg: "URL: e59c6ca5938fc27a6995e30fc10b6482
#
# Date: Not s"
# ham -- msg: "I think with the confusion and all, we should give"
# ham -- msg: "On Mon, 2 Sep 2002, Justin Mason wrote:
#
#
#
# =>http:"
# ham -- msg: "; Mon, 2 Sep 2002 15:47:48 +0100
#
#     (8.9.3/8.9.3"
# ham -- msg: "Ben Mord wrote:
#
#
#
# >     -----Original Message----"
# ham -- msg: "So far today, I've found eff.org and mandrakesoft."
# ham -- msg: "http://www.post-gazette.com/columnists/20020905bri"
# ham -- msg: "; Tue, 27 Aug 2002 19:28:29 +0100
#
#     (8.9.3/8.9."
# ham -- msg: "I love the absurd sense of humor it takes to build"
# ham -- msg: "URL: http://www.newsisfree.com/click/-3,8015194,14"
# ham -- msg: "----- Original Message -----
#
#
#
# > As I've said bef"
# ham -- msg: "; Wed, 25 Sep 2002 09:03:43 +0100
#
#
#
# Gregor sez:
# "
# ham -- msg: "URL: http://boingboing.net/#85487893
#
# Date: Not su"
# ham -- msg: "Anarchist 'Scavenger Hunt' Raises D.C. Police Ire
# "
# ham -- msg: "[Neale Pickett]
#
# > And then, just as I was about t"
# ham -- msg: "I think I understand the feeling.  A few years ago"
# ham -- msg: "; Thu, 26 Sep 2002 16:32:37 +0100
#
#
#
# British scien"
# ham -- msg: "; Tue, 1 Oct 2002 09:36:46 +0100
#
#     (8.11.6/8.11"
# ham -- msg: "; Thu, 22 Aug 2002 12:25:08 -0700 (PDT)
#
#     sunse"
# ham -- msg: "Pass it on...
#
#
#
# 					What the Press is Reporting "
# ham -- msg: "; Fri, 23 Aug 2002 15:16:13 -0300
#
#     (BRT)
#
#
#
# Hi"
# ham -- msg: "; Tue, 24 Sep 2002 09:00:10 +0100
#
#
#
# Slashdot repo"
# ham -- msg: "; Tue, 8 Oct 2002 08:42:04 +0100
#
#     (8.11.6/8.11"
# ham -- msg: "Martin Adamson wrote:>>And we know how unbiased ME"
# ham -- msg: "; Tue, 24 Sep 2002 09:00:32 +0100
#
#
#
# Phil Wolff: D"
# ham -- msg: "; Tue, 8 Oct 2002 09:01:06 +0100
#
#
#
# *Medicine and "
# ham -- msg: "; Mon, 7 Oct 2002 02:38:54 +0100
#
#     (8.11.6/8.11"
# ham -- msg: "who watched Lathe of Heaven?  (A&E, 8 pm EDT)  who"
# ham -- msg: "; Thu, 3 Oct 2002 00:19:13 -0400
#
#
#
# I recently bro"
# ham -- msg: "http://www.hughes-family.org/bugzilla/show_bug.cgi"
# ham -- msg: "I think that this and other articles confuse Socia"
# ham -- msg: "URL: http://jeremy.zawodny.com/blog/archives/00019"
# ham -- msg: "Does anyone know if this is supported under 2.4.18"
# ham -- msg: "
#
# Of course they had to do this AFTER we purcahsed"
# ham -- msg: "--- In forteana@y..., Rachel Carthy
#
#  wrote:
#
# > A"
# ham -- msg: "> Ultimately, there was a big
#
# > disagreement abou"
# ham -- msg: "No, please post a link!
#
#
#
# Fox
#
# ----- Original Mes"
# ham -- msg: "; Fri, 13 Sep 2002 07:04:14 -0700
#
#     eclectic.kl"
# ham -- msg: "In a slightly old news story, it turns out the Chi"
# ham -- msg: "; Thu, 22 Aug 2002 10:13:48 -0400
#
#     (EDT)
#
#
#
# I "
# ham -- msg: "; Sat, 5 Oct 2002 00:14:15 +0100
#
#     (8.11.6/8.11"
# ham -- msg: "
#
# In message <200209130231.g8D2VO021580@hobbit.lin"
# ham -- msg: "Once upon a time, Mark wrote :
#
#
#
# > I remember apt"
# ham -- msg: " From the local paper this morning.
#
# "Canadians ea"
# ham -- msg: "URL: http://scriptingnews.userland.com/backissues/"
# ham -- msg: "URL: http://scriptingnews.userland.com/backissues/"
# ham -- msg: "; Sun, 1 Sep 2002 03:00:22 +0100
#
#     (Exim 3.35 #"
# ham -- msg: "
#
# --RnlQjJ0d97Da+TV1
#
# Content-Type: text/plain; ch"
# ham -- msg: "On Wed, 18 Sep 2002, R. A. Hettinga wrote:
#
# --]I k"
# ham -- msg: "; Wed, 28 Aug 2002 15:08:37
#
#     -0700
#
#     #1 (De"
# ham -- msg: "i agree with rob. i think if the phones (and mms i"
# ham -- msg: "URL: http://www.joelonsoftware.com/news/20020913.h"
# ham -- msg: "; Wed, 25 Sep 2002 15:30:20 -0700 (PDT)
#
#     Wed, "
# ham -- msg: "Owne Byrne:
#
# >Sure if you're willing to risk firin"
# ham -- msg: "Joe McNally writes:
#
#
#
# > What the hell is it with "
# ham -- msg: "> >  sh -c 'for f in "`folders -recurse -fast`" ; "
# ham -- msg: "Tim Chapman writes:
#
#
#
# > http://news.bbc.co.uk/1/h"
# ham -- msg: "http://www.hughes-family.org/bugzilla/show_bug.cgi"
# ham -- msg: "Once upon a time, Ville wrote :
#
#
#
# > Any plans for"
# ham -- msg: "; Wed, 28 Aug 2002 12:56:23 -0700
#
#     (authentica"
# ham -- msg: "; Fri, 13 Sep 2002 07:16:54 -0700
#
#     [130.240.20"
# ham -- msg: "
#
# --- Martin Adamson <martin@srv0.ems.ed.ac.uk>
#
# w"
# ham -- msg: "URL: http://boingboing.net/#85506950
#
# Date: Not su"
# ham -- msg: "; Thu, 3 Oct 2002 09:00:58 +0100
#
#
#
# NYT op-ed piec"
# ham -- msg: "
#
# >>> Anthony Baxter wrote
#
# > I'm currently mangli"
# ham -- msg: "One of the main strands of this 'modernisation' is"
# ham -- msg: "; Thu, 10 Oct 2002 09:00:03 +0100
#
#
#
# _The Morning "
# ham -- msg: "; Mon, 4 Feb 2002 15:56:18 GMT
#
#     auth02.nl.egwn"
# ham -- msg: "Once upon a time, Roi wrote :
#
#
#
# > oh xmms didn't "
# ham -- msg: "Wow, talk about a pheenomeenon
#
#
#
# ==
#
# http://www.i"
# ham -- msg: "URL: http://scriptingnews.userland.com/backissues/"
# ham -- msg: "Matthias Saou (matthias@rpmforge.net) wrote*:
#
# >
#
# "
# ham -- msg: "
#
# > Chuck Murcko wrote:
#
# >
#
# > > Heh, ten years ago"
# ham -- msg: "
#
# > (and no it wasnt me even though the spellingis"
# ham -- msg: "On Thu, 2002-08-29 at 01:06, Matthias Saou wrote:
# "
# ham -- msg: "I'm listed as a developer on SF and have the spamb"
# ham -- msg: "use Perl Daily Newsletter
#
#
#
# In this issue:
#
#     *"
# ham -- msg: "URL: http://jeremy.zawodny.com/blog/archives/00019"
# ham -- msg: "URL: http://boingboing.net/#85513616
#
# Date: Not su"
# ham -- msg: "; Wed, 4 Dec 2002 11:47:36 GMT
#
#     (Postfix) with"
# ham -- msg: "Related to the MS acquisition of XDegrees?
#
#
#
# ==
#
# "
# ham -- msg: "On Wed, 11 Sep 2002, Vince Puzzella wrote:
#
#
#
# > Ev"
# ham -- msg: "; Mon, 26 Aug 2002 09:50:57
#
#     -0700
#
#     [130.2"
# ham -- msg: "; Fri, 23 Aug 2002 11:31:15 +0100
#
#     (Debian)) i"
# ham -- msg: "Yannick Gingras wrote:
#
# > Is the use of "trusted h"
# ham -- msg: "; Fri, 27 Sep 2002 09:00:55 +0100
#
#
#
# (orlando sent"
# ham -- msg: "URL: http://www.newsisfree.com/click/-4,8272608,17"
# ham -- msg: "; Sun, 29 Sep 2002 09:01:30 +0100
#
#
#
# It seems like"
# ham -- msg: ">>>>> "G" == Geege Schuman
#
#  writes:
#
#
#
#     G> .."
# ham -- msg: "    id g7R9XgZ01633
#
#
#
# > Bottom line: the late Sen"
# ham -- msg: "Of the three lying politicians, which liar would y"
# ham -- msg: "; Tue, 1 Oct 2002 09:01:09 +0100
#
#
#
# (ClickOnDetroi"
# ham -- msg: "; Thu, 10 Oct 2002 09:04:24 +0100
#
#
#
# Yeay! We had "
# ham -- msg: "On Mon, 2002-10-07 at 11:54, Matthias Saou wrote:
# "
# ham -- msg: "
#
# Gotta wonder what the GPG config stuff in ~/.exm"
# ham -- msg: "
#
# --CE+1k2dSO48ffgeK
#
# ...
# ham -- msg: "Just thought i'd pass this on, my favorite radio s"
# ham -- msg: ">>>>> "U" == Udhay Shankar N <Udhay> writes:
#
#
#
#   "
# ham -- msg: "I have to say I was surprised about Jacko dangling"
# ham -- msg: "i agree with rob. i think if the phones (and mms i"
# ham -- msg: "-----BEGIN PGP SIGNED MESSAGE-----
#
# Hash: SHA1
#
#
#
# "
# ham -- msg: "let me put it /another/ way ...
#
#
#
#     f> Mike say"
# ham -- msg: "Anyone who doesn't appreciate both PLUCK and LUCK "
# ham -- msg: "; Thu, 3 Oct 2002 09:02:09 +0100
#
#
#
# *World latest:"
# ham -- msg: "; Fri, 13 Sep 2002 03:00:16 +0100
#
#     (Exim 3.35 "
# ham -- msg: "Eventually, individuals and postmasters should be "
# ham -- msg: "Once upon a time, Brian wrote :
#
#
#
# > hey i have a "
# ham -- msg: "Update of /cvsroot/spamassassin/spamassassin/rules"
# ham -- msg: "Matthias Saou (matthias@egwn.net) wrote*:
#
# >You're"
# ham -- msg: "; Mon, 7 Oct 2002 09:00:42 +0100
#
#
#
# As audiences b"
# ham -- msg: "[Tim]
#
# > Another area for potentially fruitful stu"
# ham -- msg: "; Fri, 13 Sep 2002 11:27:37 -0700 (PDT)
#
#     Fri, "
# ham -- msg: "Once upon a time, Roi wrote :
#
#
#
# > The new spec di"
# ham -- msg: "; Mon, 30 Sep 2002 09:01:49 +0100
#
#
#
# If you've bee"
# ham -- msg: "[Jeremy]
#
# > This helps a lot!
#
#
#
# Possibly.  I chec"
# ham -- msg: "At 12:01 PM -0700 on 9/17/02, James Rogers wrote:
# "
# ham -- msg: "On Thursday 29 August 2002 16:39 CET Mike Burger w"
# ham -- msg: "; Tue, 27 Aug 2002 00:34:53 +0100
#
#     (8.11.6/8.1"
# ham -- msg: "; Fri, 4 Oct 2002 09:00:04 +0100
#
#
#
# - _Phil Ringna"
# ham -- msg: "
#
# Theo,
#
#
#
# Thank you very much, it solves the prob"
# ham -- msg: "URL: http://www.newsisfree.com/click/-5,8086490,14"
# ham -- msg: "On Sun, 1 Sep 2002, Bill Stoddard wrote:
#
#
#
# > >
#
# >"
# ham -- msg: "; Thu, 3 Oct 2002 23:03:26 +0100
#
#     (8.11.6/8.11"
# ham -- msg: "; Wed, 11 Sep 2002 21:43:38 +0100
#
#     listman.red"
# ham -- msg: "> Its possibly a different Shauna Lowery: The one "
# ham -- msg: "; Tue, 24 Sep 2002 09:00:36 +0100
#
#
#
# Janis Ian, a "
# ham -- msg: "; Fri, 6 Sep 2002 09:32:00 +0100
#
#     with ESMTP i"
# ham -- msg: "
#
# It wasn't gloating, it was one for the horror fi"
# ham -- msg: "URL: http://www.joelonsoftware.com/news/20020917.h"
# ham -- msg: ">Helen & Mike wrote:
#
# >
#
# >>  Chat tends to be on i"
# ham -- msg: "; Mon, 2 Dec 2002 03:23:18 GMT
#
#     (8.11.6/8.11.6"
# ham -- msg: "--==_Exmh_-1581861840P
#
# Content-Type: text/plain; "
# ham -- msg: "; Tue, 8 Oct 2002 09:01:22 +0100
#
#
#
# The medicine p"
# ham -- msg: "; Wed,  2 Oct 2002 14:42:50 -0700 (PDT)
#
#     mayna"
# ham -- msg: "The timtest module seems to contain an enormous bo"
# ham -- msg: "; Fri, 4 Oct 2002 22:56:33 +0100
#
#     (8.11.6/8.11"
# ham -- msg: "URL: http://www.newsisfree.com/click/-6,8572778,21"
# ham -- msg: "On Mon, Feb 04, 2002 at 05:04:08PM +0200, Peter Pe"
# ham -- msg: "; Thu, 10 Oct 2002 09:04:08 +0100
#
#
#
# *Media:* *Pet"
# ham -- msg: "On Mon, 16 Sep 2002, Stephen D. Williams wrote:
#
#
# "
# ham -- msg: "Has anyone noticed a drop in razor-check performan"
# ham -- msg: "I have failed dependencies in RPM database to I am"
# ham -- msg: "X-Habeas-Swe-1: winter into spring
#
# X-Habeas-Swe-2"
# ham -- msg: "
#
# --sHrvAb52M6C8blB9
#
# Content-Type: text/plain; ch"
# ham -- msg: "URL: http://www.livejournal.com/talkread.bml?journ"
# ham -- msg: "URL: http://www.newsisfree.com/click/-4,8278079,21"
# ham -- msg: "> The only circumstances in which a business will "
# ham -- msg: "Done
#
#
#
# >>>Robert Elz said:
#
#  > I suspect that as "
# ham -- msg: "; Thu, 26 Sep 2002 16:32:27 +0100
#
#
#
# Shining a las"
# ham -- msg: "Interesting.  It's possible, of course, that the s"
# ham -- msg: "; Wed, 28 Aug 2002 09:11:36 +0100
#
#     (8.9.3/8.9."
# spam -- msg: "
#
# ------=_NextPart_001_0004_01C2655A.4ABB3500
#
# Con"
# ham -- msg: "On Thursday 05 September 2002 04:10 CET Mike Burge"
# ham -- msg: "; Wed, 2 Oct 2002 03:06:00 +0000
#
#
#
# http://www.qui"
# ham -- msg: "This is for those that have interacted with D Wine"
# ham -- msg: "URL: http://diveintomark.org/archives/2002/10/01.h"
# ham -- msg: "If you need to store a database password, then
#
# cl"
# ham -- msg: "On Sun, 1 Sep 2002, Mr. FoRK wrote:
#
#
#
# > > 6.  Har"
# ham -- msg: "; Sat, 2 Feb 2002 21:16:51 GMT
#
#     auth02.nl.egwn"
# ham -- msg: "
#
# On Thursday, August 22, 2002, at 10:24  AM, Just"
# ham -- msg: "; Thu, 3 Oct 2002 09:02:11 +0100
#
#
#
# *Business:* Fe"
# ham -- msg: "; Tue, 27 Aug 2002 05:25:53 +0000
#
#
#
# (Via Robot Wi"
# ham -- msg: "[Tim]
#
# >> I'd prefer to strip HTML tags from every"
# ham -- msg: "URL: http://www.newsisfree.com/click/-3,8714365,14"
# ham -- msg: "URL: http://www.newsisfree.com/click/-6,8572784,21"
# ham -- msg: "I noticed a drop in checks, and did some tests.  I"
# ham -- msg: "Uh, WWII Enigma was cracked at Bletchly Park, base"
# ham -- msg: "Once upon a time, ""Angles" wrote :
#
#
#
# > FYI, This"
# ham -- msg: "URL: http://www.newsisfree.com/click/-1,8381139,21"
# ham -- msg: "; Thu, 10 Oct 2002 09:04:08 +0100
#
#
#
# *Conservative"
# ham -- msg: "URL: http://www.newsisfree.com/click/-4,7132396,15"
# ham -- msg: "> > Maybe.  I batch messages using fetchmail (don'"
# ham -- msg: "XviD [1] is a project to make GPL divx codecs. Sig"
# ham -- msg: "oops, I am bad, I need to learn how to spell......"
# ham -- msg: "use Perl Daily Newsletter
#
#
#
# In this issue:
#
#     *"
# ham -- msg: "; Thu, 26 Sep 2002 16:27:53 +0100
#
#
#
# Test your kno"
# ham -- msg: "
#
# --- begin forwarded text
#
#
#
#
#
# Subject: [dgc.chat"
# ham -- msg: "; Tue, 17 Sep 2002 22:53:07 +0100
#
#     Tue, 17 Sep"
# ham -- msg: "CDale URLed thusly:
#
# >http://www.news.harvard.edu/"
# ham -- msg: "Now that I have spam assassin and mailscanner work"
# ham -- msg: "On Fri, Feb 01, 2002 at 05:41:32PM +0200, Harri Ha"
# ham -- msg: "SpamAssassin is hurting democracy!
#
# Owen
#
# --------"
# ham -- msg: "Across my data, all-caps DATE, SUBJECT, TO, etc in"
# ham -- msg: "
#
# "Michael Moncur" said:
#
#
#
# > My corpus is about 5"
# ham -- msg: "SpamTalk said:
#
# > Probably better than the "spam p"
# ham -- msg: "> I guess MUA-level filtering is just a fallback f"
# ham -- msg: "URL: http://boingboing.net/#85528777
#
# Date: Not su"
# ham -- msg: "; Mon, 7 Oct 2002 09:00:41 +0100
#
#     Production
#
# "
# ham -- msg: "; Wed, 25 Sep 2002 09:00:23 +0100
#
#     our right t"
# ham -- msg: "Once upon a time, Jesse wrote :
#
#
#
# > On Fri, 20 Se"
# ham -- msg: "URL: http://scriptingnews.userland.com/backissues/"
# ham -- msg: "--==_Exmh_948625160P
#
# Content-Type: text/plain; ch"
# ham -- msg: "
#
#
#
# Looks useful. Hopefully, they'll put up some m"
# ham -- msg: "URL: http://www.newsisfree.com/click/-3,8714364,14"
# ham -- msg: "So then, Guido van Rossum <guido@python.org> is al"
# ham -- msg: "On Fri, 6 Sep 2002, Kragen Sitaker wrote:
#
#
#
# > Ada"
# ham -- msg: "Mark Twomey joked:
#
# >  >erm... it runs Solaris x86"
# ham -- msg: "; Mon, 23 Sep 2002 10:39:34 -0700 (PDT)
#
#     by dr"
# ham -- msg: "Guido van Rossum wrote:
#
# > I personally don't thin"
# ham -- msg: "URL: http://www.aaronsw.com/weblog/000622
#
# Date: 2"
# ham -- msg: "As well as the usual spam, it also has customers c"
# ham -- msg: "> It's this section of spamassassin.raw:
#
# >
#
# > <<<"
# ham -- msg: "use Perl Daily Headline Mailer
#
#
#
# Damian Conway Pu"
# ham -- msg: "On Wednesday 28 August 2002 16:45 CET Steve Thomas"
# ham -- msg: "; Thu, 10 Oct 2002 09:00:05 +0100
#
#
#
# - _OSNews.com"
# ham -- msg: "
#
# I have a couple of small issues, and I'm not sur"
# ham -- msg: "; Thu, 26 Sep 2002 16:29:31 +0100
#
#
#
# Back when 64K"
# ham -- msg: "from slate's "today's papers":
#
# The New York Tim"
# ham -- msg: "; Tue, 8 Oct 2002 20:03:31 +0100
#
#     (Postfix) wi"
# ham -- msg: "Once upon a time, Thomas wrote :
#
#
#
# > Should I exp"
# ham -- msg: "Quoting Paul Linehan (plinehan@yahoo.com):
#
#
#
# > Th"
# ham -- msg: "; Mon,  2 Sep 2002 23:17:40 -0700 (PDT)
#
#     venus"
# ham -- msg: "> Russell Turpin:
#
# > > That depends on how the lis"
# ham -- msg: "[Neil Schemenauer]
#
# > Woops.  I didn't have the su"
# ham -- msg: "At 01:12 AM 8/24/02 -0700, Adam L. Beberg wrote:
#
# "
# ham -- msg: " of
#
#     "Wed, 04 Sep 2002 18:25:44 EDT."
#
#
#
# X-Hab"
# ham -- msg: "
#
#
#
# > Martin Mentioned:
#
# > >I've used this a few t"
# ham -- msg: "Bitbitch writes:
#
# > Listen.  If you pull numbers l"
# ham -- msg: "JoeBar wrote:
#
# >C is more reliable than Java??
#
#
#
# "
# ham -- msg: "On Mon, 23 Sep 2002, Russell Turpin wrote:
#
#
#
# --]H"
# ham -- msg: "> From: Owen Byrne <owen@permafrost.net>
#
# > A flip"
# ham -- msg: "http://www.hughes-family.org/bugzilla/show_bug.cgi"
# ham -- msg: "
#
#
#
# > How were these msgs broken up into the 5 set"
# ham -- msg: "> (Please feel free to forward this message to oth"
# ham -- msg: "URL: http://www.newsisfree.com/click/-4,8289788,14"
# ham -- msg: "
#
# This may be a little off topic but thought peopl"
# ham -- msg: "what takes time and money: noting the amounts of e"
# ham -- msg: "Once upon a time, Hesty wrote :
#
#
#
# > > Where you c"
# ham -- msg: "http://www.hughes-family.org/bugzilla/show_bug.cgi"
# ham -- msg: "    Date:        Mon, 30 Sep 2002 14:53:33 -0500
#
# "
# ham -- msg: "; Fri, 1 Feb 2002 06:55:04 GMT
#
#     auth02.nl.egwn"
# ham -- msg: "
#
#
#
#
#
# EL> On Mon, 9 Sep 2002 bitbitch@magnesium.ne"
# ham -- msg: "
#
# I stand corrected --- I'd thought I'd seen a dis"
# ham -- msg: "; Mon, 7 Oct 2002 09:00:49 +0100
#
#
#
# We in the game"
# ham -- msg: "http://www.hughes-family.org/bugzilla/show_bug.cgi"
# ham -- msg: "URL: http://www.newsisfree.com/click/-5,8304313,17"
# ham -- msg: "I found this interesting, but not very original. A"
# ham -- msg: "; Wed, 28 Aug 2002 20:27:56 -0700
#
#     03:27:47 -0"
# ham -- msg: "This is a multi part message in MIME format.
#
#
#
# --"
# ham -- msg: "; Mon, 7 Oct 2002 09:00:43 +0100
#
#
#
# For those new "
# ham -- msg: "Rare Virgin Shark Births Reported in Detroit
#
# Voic"
# ham -- msg: "On Fri, 04 Oct 2002 03:25:30 +0200
#
# Vincent <cult@"
# ham -- msg: "; Fri, 1 Feb 2002 18:39:33 GMT
#
#     auth02.nl.egwn"
# ham -- msg: "If you examine the log further, you'll see debug m"
# ham -- msg: "; Mon, 7 Oct 2002 10:42:28 +0100
#
#     (Postfix) wi"
# ham -- msg: "On Mon, Sep 09, 2002 at 05:10:23PM -0400, Rob wrot"
# ham -- msg: "; Thu, 22 Aug 2002 09:16:59 -0700
#
#     mail.hotp.c"
# ham -- msg: "; Mon, 7 Oct 2002 11:36:20 +0100
#
#     (8.11.6/8.11"
# ham -- msg: "On Tue, Oct 08, 2002 at 04:36:13PM +0200, Matthias"
# ham -- msg: "; Tue, 1 Oct 2002 09:00:05 +0100
#
#
#
# _Paul Ford_: E"
# ham -- msg: "URL: http://www.askbjoernhansen.com/archives/2002/"
# ham -- msg: "; Wed, 4 Sep 2002 20:06:15 +0100
#
#     (8.11.6/8.11"
# ham -- msg: "; Thu, 3 Oct 2002 09:01:59 +0100
#
#
#
# Bill Clinton a"
# ham -- msg: "Does anyone know what happened to vCard support in"
# ham -- msg: ">
#
# > Sorry, Shrub, your political newspeak is fall"
# ham -- msg: "jm@jmason.org (Justin Mason) writes:
#
#
#
# > Sounds a"
# ham -- msg: "URL: http://scriptingnews.userland.com/backissues/"
# ham -- msg: "; Wed, 2 Oct 2002 14:59:37 +0100
#
#     listman.redh"
# ham -- msg: "; Mon, 30 Sep 2002 22:49:16 +0100
#
#     (8.11.6/8.1"
# ham -- msg: "So, a new family moved in down the street, with tw"
# ham -- msg: "--==_Exmh_-451422450P
#
# Content-Type: text/plain; c"
# ham -- msg: "
#
# -----Original Message-----
#
# From: Crispin Cowan "
# ham -- msg: "On Mon, Sep 09, 2002 at 11:01:22AM -0700, John Hal"
# ham -- msg: "URL: http://www.newsisfree.com/click/-2,8435176,14"
# ham -- msg: "URL: http://www.livejournal.com/talkread.bml?journ"
# ham -- msg: "Clearly, it is US/NATO = Sun/IBM/OSS, USSR = MS
#
#
# "
# ham -- msg: "URL: http://scriptingnews.userland.com/backissues/"
# ham -- msg: "-----BEGIN PGP SIGNED MESSAGE-----
#
#
#
# I may be den"
# ham -- msg: "The following was personal correspondence between "
# ham -- msg: "TimH:
#
#
#
# >Its possibly a different Shauna Lowery: "
# ham -- msg: "On Thursday 19 September 2002 16:44, Michael McKay"
# ham -- msg: "; Mon, 30 Sep 2002 12:29:59 -0700
#
#     smtp-gw-cl-"
# ham -- msg: "; Mon, 30 Sep 2002 09:01:58 +0100
#
#
#
# Strangely, I "
# ham -- msg: "URL: http://www.newsisfree.com/click/-2,8676018,14"
# ham -- msg: "; Tue, 1 Oct 2002 09:01:49 +0100
#
#
#
# I am thinking "
# ham -- msg: "URL: http://jeremy.zawodny.com/blog/archives/00021"
# ham -- msg: "; Tue, 27 Aug 2002 10:02:54 +0100
#
#     listman.red"
# ham -- msg: ">     >> > ##Remove: jeremy@alum.mit.edu##
#
# >
#
# >  "
# ham -- msg: "; Mon, 09 Sep 2002 14:10:02 -0700
#
#     greeneggsns"
# ham -- msg: "use Perl Daily Newsletter
#
#
#
# In this issue:
#
#     *"
# ham -- msg: "
#
#
#
# How about this:   A bored FoRKer said:  "YAWN""
# ham -- msg: ">  > Ok, but you'll still let me leave that black "
# ham -- msg: "Same as in mplayer src package
#
# the --with and --w"
# ham -- msg: "
#
# Using Razor2 via SpamAssasin.
#
#
#
# System is Solar"
# ham -- msg: "You can also duplicate thiswith
#
#
#
# MsgChange - nos"
# ham -- msg: "On Tue, 2002-09-17 at 12:50, Justin Mason wrote:
#
# "
# ham -- msg: "Update of /cvsroot/spamassassin/spamassassin
#
# In d"
# ham -- msg: "URL: http://www.newsisfree.com/click/-5,8536504,21"
# ham -- msg: "; Wed, 2 Oct 2002 09:03:58 +0100
#
#     (8.11.6/8.11"
# ham -- msg: "Once upon a time, Ville wrote :
#
#
#
# > I assume that"
# ham -- msg: "jm@jmason.org (Justin Mason) writes:
#
#
#
# > except f"
# ham -- msg: "> On Thu, 19 Sep 2002, Bill Stoddard wrote:
#
# > --]"
# ham -- msg: "
#
# Although it looks like I'm replying to myself, I"
# ham -- msg: ">>From todays Sun:
#
# http://www.thesun.co.uk/articl"
# ham -- msg: "; Mon, 2 Sep 2002 20:17:56 +0100
#
#     (8.9.3/8.9.3"
# ham -- msg: "On Wednesday 18 September 2002 06:47 am, Robert Ha"
# ham -- msg: "JH> They are legally required to do that.  I got a"
# ham -- msg: "URL: http://www.newsisfree.com/click/-3,8702434,21"
# ham -- msg: "; Wed, 28 Aug 2002 03:00:29 +0100
#
#     (Exim 3.35 "
# ham -- msg: "
#
#
#
# > All else being equal, the terminal velocity "
# ham -- msg: "; Mon, 7 Oct 2002 13:00:08 +0100
#
#     07 Oct 2002 "
# ham -- msg: "From: Steve Speer
#
# Subject: http://english.pravda."
# ham -- msg: "http://www.guardian.co.uk/uk_news/story/0,3604,781"
# ham -- msg: "; Thu, 7 Feb 2002 14:17:26 GMT
#
#     auth02.nl.egwn"
# ham -- msg: "
#
# Just tried smartgroups: The layout of pages is p"
# ham -- msg: "SF Weekly:
#
# >Nothing's more enticing than an eveni"
# ham -- msg: " of
#
#     "Mon, 23 Sep 2002 09:56:59 BST."
#
#     <20"
# ham -- msg: "; Thu, 22 Aug 2002 17:35:21 +0100
#
#     listman.red"
# ham -- msg: "; Thu, 26 Sep 2002 16:32:35 +0100
#
#
#
# The US Air Fo"
# ham -- msg: "On Mon, 16 Sep 2002, Stephen D. Williams wrote:
#
#
# "
# ham -- msg: "URL: http://boingboing.net/#85540997
#
# Date: Not su"
# ham -- msg: "; Mon, 2 Sep 2002 11:36:42 +0100
#
#     (8.9.3/8.9.3"
# ham -- msg: "; Mon, 7 Oct 2002 09:00:14 +0100
#
#
#
# _Law.com_: Sui"
# ham -- msg: "; Thu, 26 Sep 2002 09:01:57 +0100
#
#
#
# Brian sez: Vo"
# ham -- msg: "use Perl Daily Headline Mailer
#
#
#
# PerlQT 3 Release"
# ham -- msg: "--==_Exmh_893671157P
#
# Content-Type: text/plain; ch"
# ham -- msg: "; Wed, 28 Aug 2002 15:23:54 +0100
#
#     listman.red"
# ham -- msg: "Robert Harley:
#
# >>BTW, I wasn't aware that the 1st"
# ham -- msg: "
#
# UW Email Robot said:
#
#
#
# > What is MIME?
#
#
#
# I kno"
# ham -- msg: "; Mon, 23 Sep 2002 20:49:43 -0700 (PDT)
#
#     grang"
# ham -- msg: "
#
# --- begin forwarded text
#
#
#
#
#
# Date: Wed, 25 Sep "
# ham -- msg: "> On Mon, 9 Sep 2002, Rick Baartman wrote:
#
# > > Is"
# ham -- msg: "On Sunday 01 September 2002 08:43 pm, Reza B'Far ("
# ham -- msg: "Chris Haun wrote:
#
# >
#
# > We would need someone to "
# ham -- msg: "On Mon, 23 Sep 2002, Gordon Mohr wrote:
#
# --]
#
# --]T"
# ham -- msg: "; Thu, 03 Oct 2002 17:26:01
#
#     -0700
#
#     (Debia"
# ham -- msg: "; Thu, 22 Aug 2002 07:59:15
#
#     -0700
#
#     darwin"
# ham -- msg: "Just the headlines and URLs so I don't bore y'all "
# ham -- msg: "; Thu, 22 Aug 2002 13:14:10 +0100
#
#     id
#
# ; Thu,"
# ham -- msg: "; Thu, 26 Sep 2002 16:28:45 +0100
#
#     surrenders
# "
# ham -- msg: "; Thu,  3 Oct 2002 04:30:23 -0700 (PDT)
#
#     mayna"
# ham -- msg: "Just curious if subject line capitalization can be"
# ham -- msg: "On Wed, 2 Oct 2002 10:53:24 +0200, Matthias Saou <"
# ham -- msg: "On Mon, 2002-09-30 at 09:20, Owen Byrne wrote:
#
# > "
# ham -- msg: "    <20020830002709.GA21600@elayne.kssp.upd.edu.ph"
# ham -- msg: "; Wed, 2 Oct 2002 09:02:46 +0100
#
#
#
# *World latest:"
# ham -- msg: "; Tue, 8 Oct 2002 09:00:29 +0100
#
#
#
# After discover"
# ham -- msg: "
#
# On Thursday, August 22, 2002, at 09:36  AM, Just"
# ham -- msg: "On Thu, 2002-08-29 at 00:02, Ville Skyttä wrote:
#
# "
# ham -- msg: "use Perl Daily Newsletter
#
#
#
# In this issue:
#
#     *"
# ham -- msg: "< >
#
# > I downloaded a driver from the nVidia websi"
# ham -- msg: "; Tue, 8 Oct 2002 05:11:41 +0100
#
#     08 Oct 2002 "

# %% [markdown]
# Actividades:
# - Probar correos spam nuevos y ver que resultado arroja
# - Hacer train/test para probar el modelo
